# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json
import urllib

# %%
# Set environment variables from the .env in the local environment
load_dotenv('example.env')

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
#filter_query = 'section_name:"Movies" AND type_of_material:/"Review/" AND headline:/"love/"'
filter_query = 'section_name:Movies AND type_of_material:Review AND headline:love'
fq = title_url = urllib.parse.quote(filter_query)
# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
movies_reviews_url = f"{url}api-key={nyt_api_key}&fq={fq}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}"

# %%
# Create an empty list to store the reviews
nyt_reviews =[]

# loop through pages 0-19
for p in range(20):

    # create query with a page number
    movies_reviews_url_page=f"{movies_reviews_url}&page={p+1}"
    # API results show 10 articles at a time    
    # Make a "GET" request and retrieve the JSON
    response = requests.get(movies_reviews_url_page).json()
    
    # Try and save the reviews to the reviews_list
    if len(response["response"]["docs"])>0:
        # loop through the reviews["response"]["docs"] and append each review to the list
        nyt_reviews.extend(response["response"]["docs"])

        # Print the page that was just retrieved
        print (f"Checked page {p}")      
    else:
        # Print the page number that had no results then break from the loop
        print(f"Page {p} is empty")
        break

    # Add a twelve second interval between queries to stay within API query limits
    print("Sleeping for 12 Seconds")
    time.sleep(12)
# Out:
# Checked page 0
# Sleeping for 12 Seconds
# Checked page 1
# Sleeping for 12 Seconds
# Checked page 2
# Sleeping for 12 Seconds
# Checked page 3
# Sleeping for 12 Seconds
# Checked page 4
# Sleeping for 12 Seconds
# Checked page 5
# Sleeping for 12 Seconds
# Checked page 6
# Sleeping for 12 Seconds
# Checked page 7
# Sleeping for 12 Seconds
# Checked page 8
# Sleeping for 12 Seconds
# Checked page 9
# Sleeping for 12 Seconds
# Checked page 10
# Sleeping for 12 Seconds
# Checked page 11
# Sleeping for 12 Seconds
# Checked page 12
# Sleeping for 12 Seconds
# Checked page 13
# Sleeping for 12 Seconds
# Checked page 14
# Sleeping for 12 Seconds
# Checked page 15
# Sleeping for 12 Seconds
# Checked page 16
# Sleeping for 12 Seconds
# Checked page 17
# Sleeping for 12 Seconds
# Checked page 18
# Sleeping for 12 Seconds
# Checked page 19
# Sleeping for 12 Seconds

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data

print(json.dumps(nyt_reviews[:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/01/31/movies/pamela-a-love-story-review.html",
#         "snippet": "This documentary from Ryan White rewinds, to powerful effect, on Pamela Anderson\u2019s life and fame.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Pamela, a Love Story\u2019 Review: A Frank Look Back",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Pamela, a Love Story",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Anderson, Pamela (1967- )",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "White, Ryan (Filmmaker)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Pamela, a Love Story (Movie)",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-31T12:00:05+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/01/19/movies/in-from-the-side-review.html",
#         "snippet": "In Matt Carter\u2019s gay rugby film, sports and romance smash together like two players from opposing teams.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018In From the Side\u2019 Review: Love and Rugby Play a Losing Game",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "In From the Side",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "In From the Side (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Carter, Matt (Filmmaker)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-19T17:50:16+0000",
#         "byline": {
#             "original": "By Kyle Turner",
#             "person": [
#                 {
#                     "firstname": "Kyle",
#                     "middlename": null,
#                     "lastname": "Turner",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 281
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/01/19/movies/after-love-review.html",
#         "snippet": "In this intelligent melodrama by the director Aleem Khan, a British woman discovers her husband has been leading a double life.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018After Love\u2019 Review: The Other Woman",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "After Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "After Love (2020) (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Khan, Aleem",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Scanlan, Joanna (1961- )",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-19T12:00:06+0000",
#         "byline": {
#             "original": "By Beatrice Loayza",
#             "person": [
#                 {
#                     "firstname": "Beatrice",
#                     "middlename": null,
#                     "lastname": "Loayza",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 359
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/01/05/movies/alcarras-review.html",
#         "snippet": "In this naturalistic drama from Spain, a family confronts the impending loss of its generations-old farm.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Alcarr\u00e0s\u2019 Review: Labor of Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Alcarr\u00e0s",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Simon, Carla",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Alcarras (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-05T12:00:03+0000",
#         "byline": {
#             "original": "By Devika Girish",
#             "person": [
#                 {
#                     "firstname": "Devika",
#                     "middlename": null,
#                     "lastname": "Girish",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 306
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/12/15/movies/nelly-and-nadine-review.html",
#         "snippet": "A family archive provides intimate records of a love affair that began between two women imprisoned in the Ravensbr\u00fcck concentration camp.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Nelly & Nadine\u2019 Review: An Unlikely Love, an Unlikely Record",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Nelly &amp; Nadine",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Gertten, Magnus",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Nelly & Nadine (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Content Type: Personal Profile",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Holocaust and the Nazi Era",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "World War II (1939-45)",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Women and Girls",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Homosexuality and Bisexuality",
#                 "rank": 8,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-12-15T12:00:04+0000",
#         "byline": {
#             "original": "By Teo Bugbee",
#             "person": [
#                 {
#                     "firstname": "Teo",
#                     "middlename": null,
#                     "lastname": "Bugbee",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 308
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
pd_nyt_reviews = pd.json_normalize(nyt_reviews)
pd_nyt_reviews
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/01/31/movies/pame...
# 1    https://www.nytimes.com/2023/01/19/movies/in-f...
# 2    https://www.nytimes.com/2023/01/19/movies/afte...
# 3    https://www.nytimes.com/2023/01/05/movies/alca...
# 4    https://www.nytimes.com/2022/12/15/movies/nell...
# ..                                                 ...
# 195  https://www.nytimes.com/2016/12/08/movies/fran...
# 196  https://www.nytimes.com/2016/11/22/movies/alli...
# 197  https://www.nytimes.com/2016/11/18/movies/revi...
# 198  https://www.nytimes.com/2016/11/18/movies/ali-...
# 199  https://www.nytimes.com/2016/11/04/movies/lovi...
#
#                                                snippet              source  \
# 0    This documentary from Ryan White rewinds, to p...  The New York Times
# 1    In Matt Carter’s gay rugby film, sports and ro...  The New York Times
# 2    In this intelligent melodrama by the director ...  The New York Times
# 3    In this naturalistic drama from Spain, a famil...  The New York Times
# 4    A family archive provides intimate records of ...  The New York Times
# ..                                                 ...                 ...
# 195  Frankie and Johnny’s story returns, written an...  The New York Times
# 196  “Allied” is not so much a work of art as a tri...  The New York Times
# 197  Anna Biller’s new film stars Samantha Robinson...  The New York Times
# 198  During the era surrounding World War I, in the...  The New York Times
# 199  Jeff Nichols’s “Loving” is a fictionalization ...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Documentary Fil...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Documentary Fil...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                      pub_date  word_count  \
# 0    2023-01-31T12:00:05+0000         295
# 1    2023-01-19T17:50:16+0000         281
# 2    2023-01-19T12:00:06+0000         359
# 3    2023-01-05T12:00:03+0000         306
# 4    2022-12-15T12:00:04+0000         308
# ..                        ...         ...
# 195  2016-12-08T22:05:30+0000         554
# 196  2016-11-22T21:59:34+0000         901
# 197  2016-11-17T22:14:13+0000         604
# 198  2016-11-17T22:11:30+0000         280
# 199  2016-11-03T21:53:01+0000        1031
#
#                                          headline.main headline.kicker  \
# 0     ‘Pamela, a Love Story’ Review: A Frank Look Back            None
# 1    ‘In From the Side’ Review: Love and Rugby Play...            None
# 2                 ‘After Love’ Review: The Other Woman   Critic’s Pick
# 3                     ‘Alcarràs’ Review: Labor of Love            None
# 4    ‘Nelly & Nadine’ Review: An Unlikely Love, an ...            None
# ..                                                 ...             ...
# 195      Review: ‘Frank & Lola,’ Retreading Old Ground            None
# 196  Review: ‘Allied,’ With Brad Pitt and Marion Co...            None
# 197  Review: ‘The Love Witch,’ Hell-Bent on Capturi...            None
# 198  Review: ‘Ali and Nino,’ a Love Story Set Again...            None
# 199  Review: In ‘Loving,’ They Loved. A Segregated ...            None
#
#     headline.content_kicker                           headline.print_headline  \
# 0                      None                              Pamela, a Love Story
# 1                      None                                  In From the Side
# 2                      None                                        After Love
# 3                      None                                          Alcarràs
# 4                      None                                Nelly &amp; Nadine
# ..                      ...                                               ...
# 195                    None                Tainted Love in Familiar Packaging
# 196                    None  For This Couple, All’s Ambiguous in Love and War
# 197                    None  A Dark Seductress, Hell-Bent on Capturing Hearts
# 198                    None                                              None
# 199                    None          They Fought the Law. And Their Love Won.
#
#     headline.name headline.seo headline.sub     byline.original  \
# 0            None         None         None      By Glenn Kenny
# 1            None         None         None      By Kyle Turner
# 2            None         None         None  By Beatrice Loayza
# 3            None         None         None    By Devika Girish
# 4            None         None         None       By Teo Bugbee
# ..            ...          ...          ...                 ...
# 195          None         None         None   By Manohla Dargis
# 196          None         None         None       By A.O. Scott
# 197          None         None         None       By A.O. Scott
# 198          None         None         None   By Ken Jaworowski
# 199          None         None         None   By Manohla Dargis
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 1    [{'firstname': 'Kyle', 'middlename': None, 'la...                None
# 2    [{'firstname': 'Beatrice', 'middlename': None,...                None
# 3    [{'firstname': 'Devika', 'middlename': None, '...                None
# 4    [{'firstname': 'Teo', 'middlename': None, 'las...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 196  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 197  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 198  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 199  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
# [200 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early


# save it to a new column "title"
pd_nyt_reviews['title'] = pd_nyt_reviews['headline.main'].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
pd_nyt_reviews['keywords'] = pd_nyt_reviews['keywords'].apply(extract_keywords)

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
pd_nyt_reviews.to_csv('nyt_reviews.csv')
titles = pd_nyt_reviews['title'].to_list()

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key
details_url = "https://api.themoviedb.org/3/movie/"

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
rq = 1 

# Loop through the titles
for title in titles:
    # Check if we need to sleep before making a request
    if rq == 50:
        rq = 1
        time.sleep(1)
        print("Sleeping for 1 Second")


    # Add 1 to the request counter
    rq = rq+1
    title_url = urllib.parse.quote(title)
    search_url = f"{url}{title_url}{tmdb_key_string}"
    # Perform a "GET" request for The Movie Database
    search_response = requests.get(search_url).json()
    #print(f"{search_url}")
    #print(json.dumps(search_response, indent=4))

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.

    try:
        # Get movie id
        movie_id = search_response['results'][0]['id']

        # Make a request for a the full movie details
        # Execute "GET" request with url
        details_response = requests.get(f"{details_url}{movie_id}?api_key={tmdb_api_key}").json()
        
        # Extract the genre names into a list
        genres = [o['name'] for o in details_response['genres']]

        # Extract the spoken_languages' English name into a list
        spoken = [o['english_name'] for o in details_response['spoken_languages']]

        # Extract the production_countries' name into a list
        production = [o['name'] for o in details_response['production_countries']]
        
        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        movie = {
            'title': title,
            'original_title': details_response['original_title'],
            'budget': details_response['budget'],
            'original_language': details_response['original_language'],
            'homepage': details_response['homepage'],
            'overview': details_response['overview'],
            'popularity': details_response['popularity'],
            'runtime': details_response['runtime'],
            'revenue': details_response['revenue'],
            'release_date': details_response['release_date'],
            'vote_average': details_response['vote_average'],
            'vote_count': details_response['vote_count'],
            'genres': genres,
            'spoken_languages': spoken,
            'production_countries': production
        }
        tmdb_movies_list.append(movie)
        # Print out the title that was found
        print(f"{title} found")
    except:
        print(f"{title} not found")
# Out:
# Pamela, a Love Story found
# In From the Side found
# After Love found
# Alcarràs found
# Nelly & Nadine found
# Lady Chatterley’s Lover found
# The Sound of Christmas found
# The Inspection found
# Bones and All found
# My Policeman found
# About Fate found
# Waiting for Bojangles found
# I Love My Dad found
# A Love Song found
# Alone Together found
# Art of Love found
# The Wheel found
# Thor: Love and Thunder found
# Both Sides of the Blade found
# Fire of Love found
# Love & Gelato found
# Stay Prayed Up found
# Benediction found
# Dinner in America found
# In a New York Minute found
# Anaïs in Love found
# I Love America found
# See You Then found
# La Mami found
# Love After Love found
# Deep Water found
# Lucy and Desi found
# Cyrano found
# The In Between found
# Book of Love found
# Lingui, the Sacred Bonds found
# The Pink Cloud found
# A Journal for Jordan found
# West Side Story found
# Aulcie not found
# Love Is Love Is Love found
# Love Hard found
# Bergman Island found
# Hard Luck Love Song found
# South of Heaven found
# Wife of a Spy found
# Happier Than Ever found
# Together found
# Annette found
# Sleeping for 1 Second
# Resort to Love found
# Woodstock 99: Peace, Love and Rage found
# Casanova, Last Love found
# Running Against the Wind found
# Asia found
# Undine found
# This Town found
# Tu Me Manques found
# Monday found
# Ride or Die found
# Future People found
# Luz found
# Happily found
# This Is the Life found
# To All the Boys: Always and Forever found
# Young Hearts found
# Little Fish found
# Two of Us found
# Atlantis found
# Preparations to Be Together found
# Your Name Engraved Herein found
# Sylvie’s Love found
# Ariana Grande: Excuse Me, I Love You found
# Museum Town found
# Wild Mountain Thyme found
# My Psychedelic Love Story found
# 69: The Saga of Danny Hernandez found
# Ammonite found
# Love and Monsters found
# Dick Johnson Is Dead found
# Love, Guaranteed found
# Feel the Beat found
# Babyteeth found
# Spelling the Dream found
# A Secret Love found
# Love Wedding Repeat found
# Almost Love found
# Hope Gap found
# All the Bright Places found
# The Photograph found
# You Go to My Head found
# Ordinary Love found
# To All the Boys: P.S. I Still Love You found
# The Woman Who Loves Giraffes found
# Queen & Slim found
# Marriage Story found
# Cyrano, My Love found
# Pretenders found
# First Love found
# Sleeping for 1 Second
# Loro found
# Falling Inn Love found
# Hot Air found
# Love, Antosha found
# Leto found
# The Tomorrow Man found
# Asako I & II found
# The Sun Is Also a Star found
# Shéhérazade found
# Long Shot found
# Clara found
# Kalank found
# Rafiki found
# Diane found
# Five Feet Apart found
# Ash Is Purest White found
# Gloria Bell found
# Black Mother found
# The Hole in the Ground found
# How to Train Your Dragon: The Hidden World found
# A Tuba to Cuba found
# Fighting With My Family found
# Sorry Angel found
# Berlin, I Love You found
# Untogether found
# Cold War found
# If Beale Street Could Talk found
# Asher found
# The Party’s Just Beginning found
# The Great Pretender found
# Sicilian Ghost Story found
# The New Romantic found
# Pimp found
# In a Relationship found
# They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil not found
# Burning,’ Love Ignites a Divided Worl not found
# After Everything,’ a Young Love Blooms in Crisi not found
# Quincy’ Captures a Lifelong Love Affair With Musi not found
# Love, Gilda,’ a Portrait of a Brief and Brilliant Caree not found
# Tea With the Dames,’ Four Legends Dish on Acting and Lov not found
# Bel Canto,’ Music Is the Food of Love and Rebellio not found
# The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov not found
# Love, Cecil,’ an Aesthete Ahead of His Tim not found
# How to Talk to Girls at Parties found
# Rogers Park,’ Life and Love in a Chicago Neighborhoo not found
# Love & Bananas,’ Uncovering the Plight of the Asian Elephan not found
# Godard Mon Amour found
# Submergence,’ a Love Story Sunk by Geopolitic not found
# Love After Love,’ an Unflinching Look at Extended Grie not found
# Sleeping for 1 Second
# Outside In found
# Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre not found
# Keep the Change,’ Two People With Autism Find Lov not found
# The Party found
# The Housemaid,’ Twisted Love and Angry Ghosts in Vietna not found
# Forever My Girl,’ a Romance Resumes After a Long Brea not found
# Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr not found
# Lover for a Day found
# Youth,’ the People’s Dance Troupe, in Love and Wa not found
# Killing for Love’ Revisits a Virginia Murder Cas not found
# The Shape of Water’ Is Altogether Wonderfu not found
# Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr not found
# Cuba and the Cameraman’ Lavishes Love on a Country … and Castr not found
# On the Beach at Night Alone’ Zooms in on a Love Affai not found
# Thelma,’ a Woman in Love Can Burn Down the Worl not found
# Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade not found
# It Happened in L.A.,’ All That Questing After Lov not found
# God’s Own Country found
# The Mountain Between Us found
# Dina,’ a Differently Abled Love Stor not found
# In Search of Fellini found
# Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen not found
# I Do ... Until I Don’t,’ Love and Loathing in Florid not found
# Tales of an Immoral Couple’: Love Means Having to Grow U not found
# After Love’ and Regretting Every Momen not found
# The Last Face found
# Women Who Kill,’ and May Be in Love With On not found
# False Confessions,’ the Play’s Not Quite the Thin not found
# Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem not found
# The Big Sick,’ Comedy Is Hard, Love Harde not found
# Lost in Paris found
# Vincent N Roxxy,’ Love Is in the Air, N So Is Fea not found
# Everything, Everything’ Pits Love Against Diseas not found
# Hounds of Love’ Is Tense and Deadly Down Unde not found
# Harold and Lillian’ Introduces a Hollywood Power Coupl not found
# The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope not found
# The Promise’ Finds a Love Triangle in Constantinopl not found
# Frantz,’ a Mysterious Frenchman and the Wounds of Wa not found
# The Other Half found
# The Ottoman Lieutenant found
# Love & Taxes found
# Everybody Loves Somebody,’ a Rom-Com With Bit not found
# Kedi,’ Rekindling a ‘Love of Life not found
# A United Kingdom’ With Love That Tested Racial Toleranc not found
# Sophie and the Rising Sun’ Has Forbidden Love in a Foreboding Tim not found
# Paris 05:59 Théo & Hugo’ Finds Two Men Out to Get Luck not found
# Ocean Waves,’ a Tale of Young Love, Ghibli Styl not found
# Passengers’ Trapped on a Spaceship Find Love Amid Despai not found
# Frank & Lola,’ Retreading Old Groun not found
# Sleeping for 1 Second
# Allied,’ With Brad Pitt and Marion Cotillard, Uncorks a Favorite Vintag not found
# The Love Witch,’ Hell-Bent on Capturing Your Hear not found
# Ali and Nino,’ a Love Story Set Against Majestic Backdrop not found
# Loving,’ They Loved. A Segregated Virginia Did Not Love Them Back not found

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print (json.dumps(tmdb_movies_list[:5],indent=4))
# Out:
# [
#     {
#         "title": "Pamela, a Love Story",
#         "original_title": "Pamela, A Love Story",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "https://www.netflix.com/title/81590934",
#         "overview": "In her own words, through personal video and diaries, Pamela Anderson shares the story of her rise to fame, rocky romances and infamous sex tape scandal.",
#         "popularity": 17.316,
#         "runtime": 113,
#         "revenue": 0,
#         "release_date": "2023-01-30",
#         "vote_average": 6.985,
#         "vote_count": 197,
#         "genres": [
#             "Documentary"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "In From the Side",
#         "original_title": "In from the Side",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "http://www.infromthesidemovie.com",
#         "overview": "Mark, a new and inexperienced rugby club member, finds himself drawn to Warren, a seasoned first team player. When a series of happenstances at an away fixture lead to a drunken encounter, Mark and Warren unwittingly embark on a romantic affair they struggle to hide from their partners and teammates.",
#         "popularity": 15.798,
#         "runtime": 134,
#         "revenue": 0,
#         "release_date": "2022-09-16",
#         "vote_average": 7.152,
#         "vote_count": 46,
#         "genres": [
#             "Drama",
#             "Romance"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United Kingdom"
#         ]
#     },
#     {
#         "title": "After Love",
#         "original_title": "After Love",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "",
#         "overview": "Set in the port town of Dover in the South-East of England, Mary Hussain suddenly finds herself a widow following the unexpected death of her husband. A day after the burial, she discovers he has a secret just twenty-one miles across the English Channel in Calais.",
#         "popularity": 9.199,
#         "runtime": 89,
#         "revenue": 0,
#         "release_date": "2021-06-04",
#         "vote_average": 7.31,
#         "vote_count": 92,
#         "genres": [
#             "Drama"
#         ],
#         "spoken_languages": [
#             "English",
#             "Arabic",
#             "French",
#             "Urdu"
#         ],
#         "production_countries": [
#             "United Kingdom"
#         ]
#     },
#     {
#         "title": "Alcarr\u00e0s",
#         "original_title": "Alcarr\u00e0s",
#         "budget": 0,
#         "original_language": "ca",
#         "homepage": "https://www.alcarras-film.com/",
#         "overview": "In a small village in Catalonia, the peach farmers of the Sol\u00e9 family spend every summer together picking fruit from their orchard. But when plans arise to install solar panels and cut down trees, the members of this tight-knit group suddenly face eviction \u2013 and the loss of far more than their home.",
#         "popularity": 12.125,
#         "runtime": 120,
#         "revenue": 0,
#         "release_date": "2022-04-29",
#         "vote_average": 6.935,
#         "vote_count": 162,
#         "genres": [
#             "Drama"
#         ],
#         "spoken_languages": [
#             "Catalan"
#         ],
#         "production_countries": [
#             "Spain"
#         ]
#     },
#     {
#         "title": "Nelly & Nadine",
#         "original_title": "Nelly och Nadine",
#         "budget": 0,
#         "original_language": "sv",
#         "homepage": "https://www.autoimages.se/nelly_nadine",
#         "overview": "Nelly and Nadine meet in Ravensbr\u00fcck concentration camp. They spend the rest of their lives together. Decades later, Nelly\u2019s granddaughter goes in search of clues. A poignant film about a love story and the need for individual and collective remembrance.",
#         "popularity": 2.163,
#         "runtime": 92,
#         "revenue": 0,
#         "release_date": "2024-06-05",
#         "vote_average": 0.0,
#         "vote_count": 0,
#         "genres": [
#             "Documentary"
#         ],
#         "spoken_languages": [
#             "English",
#             "Spanish",
#             "French",
#             "Swedish"
#         ],
#         "production_countries": [
#             "Belgium",
#             "Norway",
#             "Sweden"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
movies_df = pd.DataFrame.from_dict(tmdb_movies_list)

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
nyt_reviewd_movies = pd_nyt_reviews.merge(movies_df, on='title')

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ['genres', 'spoken_languages', 'production_countries']


# Create a list of characters to remove
characters_to_remove =['[',']','\'']

# Loop through the list of columns to fix
for col in columns_to_fix:
    # Convert the column to type 'str'
    nyt_reviewd_movies[col] = nyt_reviewd_movies[col].astype(str)
    # Loop through characters to remove
    for ch in characters_to_remove:
        nyt_reviewd_movies[col] = nyt_reviewd_movies[col].str.replace(ch, '')


# Display the fixed DataFrame
nyt_reviewd_movies.head(5)
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/01/31/movies/pame...
# 1  https://www.nytimes.com/2023/01/19/movies/in-f...
# 2  https://www.nytimes.com/2023/01/19/movies/afte...
# 3  https://www.nytimes.com/2023/01/05/movies/alca...
# 4  https://www.nytimes.com/2022/12/15/movies/nell...
#
#                                              snippet              source  \
# 0  This documentary from Ryan White rewinds, to p...  The New York Times
# 1  In Matt Carter’s gay rugby film, sports and ro...  The New York Times
# 2  In this intelligent melodrama by the director ...  The New York Times
# 3  In this naturalistic drama from Spain, a famil...  The New York Times
# 4  A family archive provides intimate records of ...  The New York Times
#
#                                             keywords  \
# 0  subject: Documentary Films and Programs;person...
# 1  subject: Movies;creative_works: In From the Si...
# 2  subject: Movies;creative_works: After Love (20...
# 3  subject: Movies;persons: Simon, Carla;creative...
# 4  subject: Documentary Films and Programs;person...
#
#                    pub_date  word_count  \
# 0  2023-01-31T12:00:05+0000         295
# 1  2023-01-19T17:50:16+0000         281
# 2  2023-01-19T12:00:06+0000         359
# 3  2023-01-05T12:00:03+0000         306
# 4  2022-12-15T12:00:04+0000         308
#
#                                        headline.main headline.kicker  \
# 0   ‘Pamela, a Love Story’ Review: A Frank Look Back            None
# 1  ‘In From the Side’ Review: Love and Rugby Play...            None
# 2               ‘After Love’ Review: The Other Woman   Critic’s Pick
# 3                   ‘Alcarràs’ Review: Labor of Love            None
# 4  ‘Nelly & Nadine’ Review: An Unlikely Love, an ...            None
#
#   headline.content_kicker headline.print_headline  ...  \
# 0                    None    Pamela, a Love Story  ...
# 1                    None        In From the Side  ...
# 2                    None              After Love  ...
# 3                    None                Alcarràs  ...
# 4                    None      Nelly &amp; Nadine  ...
#
#                                             overview popularity runtime  \
# 0  In her own words, through personal video and d...     17.316     113
# 1  Mark, a new and inexperienced rugby club membe...     15.798     134
# 2  Set in the port town of Dover in the South-Eas...      9.199      89
# 3  In a small village in Catalonia, the peach far...     12.125     120
# 4  Nelly and Nadine meet in Ravensbrück concentra...      2.163      92
#
#   revenue release_date vote_average vote_count          genres  \
# 0       0   2023-01-30        6.985        197     Documentary
# 1       0   2022-09-16        7.152         46  Drama, Romance
# 2       0   2021-06-04        7.310         92           Drama
# 3       0   2022-04-29        6.935        162           Drama
# 4       0   2024-06-05        0.000          0     Documentary
#
#                     spoken_languages      production_countries
# 0                            English  United States of America
# 1                            English            United Kingdom
# 2      English, Arabic, French, Urdu            United Kingdom
# 3                            Catalan                     Spain
# 4  English, Spanish, French, Swedish   Belgium, Norway, Sweden
#
# [5 rows x 31 columns]

# %%
# Drop "byline.person" column
nyt_reviewd_movies = nyt_reviewd_movies.drop(['byline.person'], axis=1)

# %%
# Delete duplicate rows and reset index

nyt_reviewd_movies = nyt_reviewd_movies.drop_duplicates()

nyt_reviewd_movies.reset_index()
# Out:
#      index                                            web_url  \
# 0        0  https://www.nytimes.com/2023/01/31/movies/pame...
# 1        1  https://www.nytimes.com/2023/01/19/movies/in-f...
# 2        2  https://www.nytimes.com/2023/01/19/movies/afte...
# 3        3  https://www.nytimes.com/2023/01/05/movies/alca...
# 4        4  https://www.nytimes.com/2022/12/15/movies/nell...
# ..     ...                                                ...
# 139    139  https://www.nytimes.com/2017/07/27/movies/the-...
# 140    140  https://www.nytimes.com/2017/06/15/movies/lost...
# 141    141  https://www.nytimes.com/2017/03/09/movies/the-...
# 142    142  https://www.nytimes.com/2017/03/09/movies/revi...
# 143    143  https://www.nytimes.com/2017/03/02/movies/love...
#
#                                                snippet              source  \
# 0    This documentary from Ryan White rewinds, to p...  The New York Times
# 1    In Matt Carter’s gay rugby film, sports and ro...  The New York Times
# 2    In this intelligent melodrama by the director ...  The New York Times
# 3    In this naturalistic drama from Spain, a famil...  The New York Times
# 4    A family archive provides intimate records of ...  The New York Times
# ..                                                 ...                 ...
# 139  In war-torn Liberia, Charlize Theron and Javie...  The New York Times
# 140  The filmmakers Fiona Gordon and Dominique Abel...  The New York Times
# 141  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 142  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 143  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
#
#                                               keywords  \
# 0    subject: Documentary Films and Programs;person...
# 1    subject: Movies;creative_works: In From the Si...
# 2    subject: Movies;creative_works: After Love (20...
# 3    subject: Movies;persons: Simon, Carla;creative...
# 4    subject: Documentary Films and Programs;person...
# ..                                                 ...
# 139  subject: Movies;creative_works: The Last Face ...
# 140  creative_works: Lost in Paris (Movie);subject:...
# 141  subject: Movies;creative_works: The Other Half...
# 142  subject: Movies;creative_works: The Ottoman Li...
# 143  creative_works: Love & Taxes (Movie);persons: ...
#
#                      pub_date  word_count  \
# 0    2023-01-31T12:00:05+0000         295
# 1    2023-01-19T17:50:16+0000         281
# 2    2023-01-19T12:00:06+0000         359
# 3    2023-01-05T12:00:03+0000         306
# 4    2022-12-15T12:00:04+0000         308
# ..                        ...         ...
# 139  2017-07-27T20:29:01+0000         280
# 140  2017-06-15T19:37:09+0000         254
# 141  2017-03-09T21:54:58+0000         251
# 142  2017-03-09T21:53:12+0000         267
# 143  2017-03-02T21:44:18+0000         246
#
#                                          headline.main headline.kicker  \
# 0     ‘Pamela, a Love Story’ Review: A Frank Look Back            None
# 1    ‘In From the Side’ Review: Love and Rugby Play...            None
# 2                 ‘After Love’ Review: The Other Woman   Critic’s Pick
# 3                     ‘Alcarràs’ Review: Labor of Love            None
# 4    ‘Nelly & Nadine’ Review: An Unlikely Love, an ...            None
# ..                                                 ...             ...
# 139  Review: Aid Workers in Love and War in Sean Pe...            None
# 140  Review: Finding Love (and Slapstick) While ‘Lo...            None
# 141  Review: A Combustible Pair Find Love in ‘The O...            None
# 142  Review: Love as the World Wars, in ‘The Ottoma...            None
# 143  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
#
#     headline.content_kicker  ...  \
# 0                      None  ...
# 1                      None  ...
# 2                      None  ...
# 3                      None  ...
# 4                      None  ...
# ..                      ...  ...
# 139                    None  ...
# 140                    None  ...
# 141                    None  ...
# 142                    None  ...
# 143                    None  ...
#
#                                               overview popularity runtime  \
# 0    In her own words, through personal video and d...     17.316     113
# 1    Mark, a new and inexperienced rugby club membe...     15.798     134
# 2    Set in the port town of Dover in the South-Eas...      9.199      89
# 3    In a small village in Catalonia, the peach far...     12.125     120
# 4    Nelly and Nadine meet in Ravensbrück concentra...      2.163      92
# ..                                                 ...        ...     ...
# 139  Miguel, a heroic Spanish doctor, puts himself ...     11.708     130
# 140  Fiona visits Paris for the first time to assis...     10.522      83
# 141  A grief-stricken man and a bipolar woman fall ...      4.989     103
# 142  Lillie, a determined American woman, ventures ...     23.324     111
# 143  Love &amp; Taxes is a riveting comic tale of s...      2.860      98
#
#     revenue release_date vote_average vote_count               genres  \
# 0         0   2023-01-30        6.985        197          Documentary
# 1         0   2022-09-16        7.152         46       Drama, Romance
# 2         0   2021-06-04        7.310         92                Drama
# 3         0   2022-04-29        6.935        162                Drama
# 4         0   2024-06-05        0.000          0          Documentary
# ..      ...          ...          ...        ...                  ...
# 139       0   2017-01-11        5.605        186                Drama
# 140       0   2017-01-14        6.059        111               Comedy
# 141       0   2016-12-02        6.159         22       Drama, Romance
# 142  413844   2017-03-10        6.173        240  Romance, Drama, War
# 143       0   2017-03-03        4.000          1               Comedy
#
#                       spoken_languages              production_countries
# 0                              English          United States of America
# 1                              English                    United Kingdom
# 2        English, Arabic, French, Urdu                    United Kingdom
# 3                              Catalan                             Spain
# 4    English, Spanish, French, Swedish           Belgium, Norway, Sweden
# ..                                 ...                               ...
# 139                English, Portuguese          United States of America
# 140                             French                   Belgium, France
# 141                            English                            Canada
# 142                   Turkish, English  Turkey, United States of America
# 143                            English          United States of America
#
# [144 rows x 31 columns]

# %%
# Export data to CSV without the index
nyt_reviewd_movies.to_csv('output/nyt_reviewd_movies.csv', index=False)
